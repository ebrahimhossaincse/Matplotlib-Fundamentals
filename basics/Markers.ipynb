# %% [markdown]
# ## Point Marker (.)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [22, 1, 7, 2, 21, 11, 14, 5]
y = [24, 2, 12, 5, 5, 5, 9, 12]

# Plot with Point Marker
plt.scatter(x, y, marker='.', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Point Marker (.)')
plt.show()

# %% [markdown]
# ## Pixel Marker (,)

# %%
plt.scatter(x, y, marker=',', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Pixel Marker (,)')
plt.show()

# %% [markdown]
# ## Circle Marker (o)

# %%
plt.scatter(x, y, marker='o', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Circle Marker (o)')
plt.show()

# %% [markdown]
# ## Triangle Down Marker (v)

# %%
plt.scatter(x, y, marker='v', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Triangle Down Marker (v)')
plt.show()

# %% [markdown]
# ## Triangle Up Marker (^)

# %%
plt.scatter(x, y, marker='^', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Triangle Up Marker (^)')
plt.show()

# %% [markdown]
# ## Triangle Left Marker (<)

# %%
plt.scatter(x, y, marker='<', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Triangle Left Marker (<)')
plt.show()

# %% [markdown]
# ## Triangle Right Marker (>)

# %%
plt.scatter(x, y, marker='>', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Triangle Right Marker (>)')
plt.show()

# %% [markdown]
# ## Downward-pointing Triangle Marker (1)

# %%
plt.scatter(x, y, marker='1', s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot with Downward-pointing Triangle Marker (1)')
plt.show()
